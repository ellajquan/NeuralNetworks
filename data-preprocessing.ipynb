# %%
import torch
from torchvision import transforms
from PIL import Image
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
import os

# %% [markdown]
# # --------------------
# #Image Preprocessing (DICOM)
# # --------------------

# %%
import pydicom
import os
from PIL import Image
from torchvision import transforms
import torch

# Base directory containing the DICOM files
base_dir = '/Users/ellaquan/Project/Extracted_DICOM_500'  # Update this path

# Define image transformations
image_preprocess = transforms.Compose([
    transforms.Resize((224, 224)),  # Resizing the image to 224x224
    transforms.ToTensor(),  # Convert the image to a PyTorch tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # ImageNet normalization
])

# Augmentation transformations for training (optional)
augmentation_transforms = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.RandomResizedCrop(224),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to convert DICOM to PIL image
def dicom_to_pil(dicom_path):
    # Load the DICOM file
    dicom_img = pydicom.dcmread(dicom_path)
    
    # Extract pixel array (this will be in grayscale)
    pixel_array = dicom_img.pixel_array
    
    # Normalize to range 0-255 and convert to uint8 type for image compatibility
    pixel_array = (pixel_array - pixel_array.min()) / (pixel_array.max() - pixel_array.min()) * 255
    pixel_array = pixel_array.astype('uint8')
    
    # Convert to PIL image (grayscale 'L' mode)
    pil_image = Image.fromarray(pixel_array).convert('RGB')  # Convert grayscale to RGB for preprocessing
    return pil_image

# Function to preprocess a DICOM image (with optional augmentation)
def preprocess_dicom_image(dicom_path, augment=False):
    pil_image = dicom_to_pil(dicom_path)  # Convert DICOM to PIL image
    
    # Apply augmentation or standard preprocessing
    if augment:
        preprocessed_image = augmentation_transforms(pil_image)
    else:
        preprocessed_image = image_preprocess(pil_image)
    
    return preprocessed_image

# Function to iterate over a folder of DICOM files and preprocess each image
def process_dicom_folder(base_dir, augment=False):
    preprocessed_images = []  # List to store the preprocessed images
    for root, dirs, files in os.walk(base_dir):
        for file_name in files:
            if file_name.endswith('.dcm'):  # Check for DICOM files
                dicom_file_path = os.path.join(root, file_name)
                
                try:
                    print(f"Processing: {dicom_file_path}")  # Debugging line

                    # Preprocess the DICOM image
                    preprocessed_image = preprocess_dicom_image(dicom_file_path, augment=augment)
                    
                    # Append preprocessed image to list (for later use)
                    preprocessed_images.append(preprocessed_image)
                    
                except Exception as e:
                    print(f"Error processing {dicom_file_path}: {e}")
    
    return preprocessed_images
# Function to save preprocessed images
def save_preprocessed_images(base_dir, output_dir, augment=False):
    os.makedirs(output_dir, exist_ok=True)  # Create the output directory if it doesn't exist
    for root, dirs, files in os.walk(base_dir):
        for file_name in files:
            if file_name.endswith('.dcm'):  # Check for DICOM files
                dicom_file_path = os.path.join(root, file_name)
                
                try:
                    print(f"Processing: {dicom_file_path}")  # Debugging line

                    # Preprocess the DICOM image
                    preprocessed_image = preprocess_dicom_image(dicom_file_path, augment=augment)
                    
                    # Convert the preprocessed tensor back to PIL Image and save
                    preprocessed_image_pil = transforms.ToPILImage()(preprocessed_image)  # Convert tensor back to PIL
                    output_path = os.path.join(output_dir, f"{os.path.splitext(file_name)[0]}.png")
                    preprocessed_image_pil.save(output_path)
                    print(f"Saved preprocessed image to: {output_path}")
                    
                except Exception as e:
                    print(f"Error processing {dicom_file_path}: {e}")#

# Example usage: Save preprocessed images to an output folder
#output_directory = '/Users/ellaquan/Project/Preprocessed_Images'
#save_preprocessed_images(base_dir, output_directory, augment=True)

# Example usage:
preprocessed_images = process_dicom_folder(base_dir, augment=True)

# Optionally, you can stack preprocessed images into a batch tensor for model input
#if preprocessed_images:
#    batched_tensor = torch.stack(preprocessed_images)
#    print(f"Batched tensor shape: {batched_tensor.shape}")

# Function to save a tensor to a file
def save_batched_tensor(batched_tensor, file_path):
    torch.save(batched_tensor, file_path)
    print(f"Saved batched tensor to: {file_path}")


# Stack preprocessed images into a batch tensor for model input
if preprocessed_images:
    batched_tensor = torch.stack(preprocessed_images)
    print(f"Batched tensor shape: {batched_tensor.shape}")
    
    # Save the batched tensor to a file
    output_tensor_file = '/Users/ellaquan/Project/batched_tensor.pt'  # Path to save the batched tensor
    save_batched_tensor(batched_tensor, output_tensor_file)
# Out:
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0070_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0084_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0046_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0297_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0047_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0255_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1523_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0025_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1178_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0414_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1548_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0607_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0631_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0423_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1125_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0078_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0414_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0422_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0079_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1577_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0263_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1185_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0441_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0070_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0084_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0084_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0477_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0254_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0046_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0085_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0263_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0297_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0255_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0079_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1523_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0422_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0414_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1178_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1548_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0607_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0415_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0631_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1125_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0013_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0422_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0448_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0079_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1577_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0071_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0263_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1185_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0046_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0483_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0070_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0441_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0254_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0296_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0084_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0477_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0047_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0664_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0085_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1170_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0414_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0606_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0025_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0078_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0415_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0423_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0236_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0423_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0200_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0078_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0699_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0025_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0013_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0448_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1184_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0071_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0690_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0047_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0639_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0483_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0262_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0070_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0441_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0254_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0046_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0477_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0483_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0296_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0047_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0071_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0085_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0664_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1170_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0448_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0013_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0606_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0025_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0415_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0236_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0423_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0200_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0415_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0699_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0078_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0422_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0013_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0079_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0448_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1184_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0690_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0071_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0085_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0263_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0639_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0262_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0477_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0483_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0441_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0254_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0243_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0051_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0862_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0618_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0242_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0863_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0274_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0280_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1375_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0809_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0619_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0058_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1317_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0288_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1727_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0289_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0610_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0800_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0221_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0836_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0626_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0610_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0435_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0627_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1343_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1381_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0274_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0280_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1718_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0645_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0896_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0067_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1328_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0854_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0051_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0862_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0281_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0242_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0280_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0673_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0619_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0809_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1375_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0228_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0058_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1317_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0611_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0032_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1727_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0289_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0800_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0610_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0626_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0626_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0836_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0217_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0289_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0435_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1343_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1381_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0619_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0687_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1718_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0274_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0242_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0275_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0067_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0862_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0896_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0854_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1328_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0281_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0243_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0618_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0280_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0673_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0863_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0645_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0228_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0288_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1726_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0627_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0032_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0611_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0059_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0221_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0610_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0217_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0221_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0004_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0627_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0288_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1710_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0855_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0645_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0687_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0863_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0897_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0274_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0618_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1380_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1342_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0243_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0275_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1719_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0275_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0281_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0862_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0243_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0618_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0863_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0673_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0687_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0242_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0228_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0619_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0288_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1726_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0032_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0611_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0289_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0059_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0221_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0217_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0217_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0626_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0004_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0611_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0627_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0032_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1710_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0228_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0645_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0855_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0897_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0673_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0687_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1380_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1342_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1719_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0275_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0281_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0076_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0264_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1140_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0484_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0077_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0636_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0425_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1149_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0014_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0048_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0413_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0425_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0049_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0299_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0600_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0412_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0083_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0470_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0252_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0082_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0290_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0609_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0609_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0264_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1140_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0077_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0083_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0446_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0636_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0424_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0207_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1149_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0413_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0048_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0048_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0479_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0413_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0022_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0299_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0600_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0077_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0083_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0040_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0252_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0290_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0609_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1183_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0697_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0076_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0082_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0446_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0265_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0470_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0484_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0207_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0412_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0424_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0049_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0014_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0637_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0479_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0298_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0022_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0014_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1525_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0049_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0231_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0412_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0470_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0484_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0291_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0253_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0076_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0082_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0663_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0040_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1183_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0040_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0076_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0697_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0446_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0484_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0265_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0077_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0207_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0424_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0014_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0637_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0022_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0479_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0298_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0479_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0048_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0022_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0413_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0049_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1525_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0424_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0231_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0207_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0412_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0291_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0083_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0470_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0446_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0253_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0663_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0082_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0040_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0609_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0838_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0628_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1344_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0245_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0680_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0629_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0853_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0272_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0891_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0210_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0621_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0831_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1716_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1326_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0898_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0035_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0616_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0621_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0807_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0617_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0865_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0286_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1319_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0056_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0674_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0245_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0219_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1344_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0628_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0838_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0642_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0853_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0891_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0617_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0831_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0621_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1716_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0689_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0620_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1326_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0898_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0226_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0617_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0807_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1319_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0865_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0853_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0244_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0056_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0245_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0628_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0219_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0061_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0890_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0674_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0680_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0642_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0852_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0629_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1345_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0272_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0286_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0451_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0621_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0433_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0210_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0068_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0689_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0899_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0620_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0035_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0003_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0616_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1717_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1721_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0616_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0035_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0210_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0226_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0244_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0272_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0286_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0467_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1373_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0629_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0245_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0864_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0674_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0680_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0628_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0219_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0680_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0890_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0061_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0852_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0642_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1345_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0629_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0272_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0451_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0853_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0244_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0433_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0226_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0210_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0899_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0689_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0068_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0620_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0003_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1717_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1721_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0616_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0620_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0035_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0689_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0617_1-4.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0226_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0244_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0467_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0286_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-1373_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0642_1-3.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0674_1-1.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D1-0864_1-2.dcm
# Processing: /Users/ellaquan/Project/Extracted_DICOM_500/D2-0219_1-3.dcm
# Batched tensor shape: torch.Size([500, 3, 224, 224])
# Saved batched tensor to: /Users/ellaquan/Project/batched_tensor.pt

# %% [markdown]
# # --------------------
# # Clinical Data Preprocessing
# # --------------------

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
import torch
import numpy as np
import pandas as pd

# Load clinical data from Excel
clinical_data_path = '/Users/ellaquan/Project/CMMD-data/CMMD_clinicaldata_revision.xlsx'
clinical_df = pd.read_excel(clinical_data_path) 

# Select the first 500 unique IDs
clinical_df = clinical_df.drop_duplicates(subset='ID1').head(500)

# Select relevant features (columns)
clinical_features = clinical_df[['Age', 'abnormality', 'classification', 'subtype']]

# Normalize continuous variables
scaler = StandardScaler()
continuous_features = ['Age']  # Ensure 'Age' matches the column name in your dataset
clinical_df[continuous_features] = scaler.fit_transform(clinical_df[continuous_features])

# One-hot encode categorical variables
categorical_features = ['abnormality', 'classification', 'subtype']
encoder = OneHotEncoder(sparse_output=False)  # Updated parameter name
encoded_categorical = encoder.fit_transform(clinical_df[categorical_features])

# Combine the normalized continuous features and encoded categorical features
preprocessed_clinical_data = np.hstack((clinical_df[continuous_features].values, encoded_categorical))

# Convert the combined clinical data to a PyTorch tensor
preprocessed_clinical_data_tensor = torch.tensor(preprocessed_clinical_data, dtype=torch.float32)

# %% [markdown]
# # --------------------
# # Splitting Data
# # --------------------

# %%
# Split data into training, validation, and test sets (for both image and clinical data)
def split_data(image_paths, clinical_data, test_size=0.2, val_size=0.1):
    # First split into training+validation and test sets
    train_image_paths, test_image_paths, train_clinical_data, test_clinical_data = train_test_split(
        image_paths, clinical_data, test_size=test_size, random_state=42
    )
    
    # Then split the training set into training and validation sets
    train_image_paths, val_image_paths, train_clinical_data, val_clinical_data = train_test_split(
        train_image_paths, train_clinical_data, test_size=val_size, random_state=42
    )
    
    return (train_image_paths, val_image_paths, test_image_paths,
            train_clinical_data, val_clinical_data, test_clinical_data)

# Example of splitting data
image_paths = ['/path/to/image1.png', '/path/to/image2.png', '/path/to/image3.png']  # List of image paths
preprocessed_clinical_data = preprocessed_clinical_data_tensor.numpy()  # Convert to numpy for splitting

train_img, val_img, test_img, train_clinical, val_clinical, test_clinical = split_data(image_paths, preprocessed_clinical_data)

print(f"Training Set: {len(train_img)} images, {len(train_clinical)} clinical records")
print(f"Validation Set: {len(val_img)} images, {len(val_clinical)} clinical records")
print(f"Test Set: {len(test_img)} images, {len(test_clinical)} clinical records")
